# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('airfoil_self_noise.dat', sep='\t', header=None)

# %% [raw]
# This problem has the following inputs:
# 1. Frequency, in Hertzs.
# 2. Angle of attack, in degrees.
# 3. Chord length, in meters.
# 4. Free-stream velocity, in meters per second.
# 5. Suction side displacement thickness, in meters.
#
# The only output is:
# 6. Scaled sound pressure level, in decibels.

# %%
df.columns=['Frequency', 'Angle of attack', 'Chord length', 'Free-stream velocity', 'Suction side displacement thickness', 'Scaled sound pressure level']

# %%
df
# Out:
#       Frequency  Angle of attack  Chord length  Free-stream velocity  \
# 0           800              0.0        0.3048                  71.3
# 1          1000              0.0        0.3048                  71.3
# 2          1250              0.0        0.3048                  71.3
# 3          1600              0.0        0.3048                  71.3
# 4          2000              0.0        0.3048                  71.3
# ...         ...              ...           ...                   ...
# 1498       2500             15.6        0.1016                  39.6
# 1499       3150             15.6        0.1016                  39.6
# 1500       4000             15.6        0.1016                  39.6
# 1501       5000             15.6        0.1016                  39.6
# 1502       6300             15.6        0.1016                  39.6
#
#       Suction side displacement thickness  Scaled sound pressure level
# ...

# %%
# First do train test split

# %%
df.isnull().sum()
# Out:
# Frequency                              0
# Angle of attack                        0
# Chord length                           0
# Free-stream velocity                   0
# Suction side displacement thickness    0
# Scaled sound pressure level            0
# dtype: int64

# %%
X = df.iloc[:,:-1]
y = df['Scaled sound pressure level']

# %%
y
# Out:
# 0       126.201
# 1       125.201
# 2       125.951
# 3       127.591
# 4       127.461
#          ...
# 1498    110.264
# 1499    109.254
# 1500    106.604
# 1501    106.224
# 1502    104.204
# Name: Scaled sound pressure level, Length: 1503, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.head()
# Out:
#       Frequency  Angle of attack  Chord length  Free-stream velocity  \
# 845         500             11.2        0.0508                  71.3
# 1026      10000              4.8        0.0254                  55.5
# 621        2000              7.2        0.1524                  39.6
# 1371        630              6.7        0.1016                  31.7
# 195        6300              0.0        0.2286                  71.3
#
#       Suction side displacement thickness
# 845                              0.014072
# 1026                             0.000873
# 621                              0.009092
# 1371                             0.005929
# 195                              0.002143

# %%
import seaborn as sns
sns.pairplot(X_train)

# %%
import matplotlib.pyplot as plt
X_train.corr()
# Out:
#                                      Frequency  Angle of attack  Chord length  \
# Frequency                             1.000000        -0.273327     -0.000324
# Angle of attack                      -0.273327         1.000000     -0.498257
# Chord length                         -0.000324        -0.498257      1.000000
# Free-stream velocity                  0.125247         0.058603      0.013061
# Suction side displacement thickness  -0.239878         0.762567     -0.220849
#
#                                      Free-stream velocity  \
# Frequency                                        0.125247
# Angle of attack                                  0.058603
# Chord length                                     0.013061
# Free-stream velocity                             1.000000
# Suction side displacement thickness             -0.000519
#
#                                      Suction side displacement thickness
# Frequency                                                      -0.239878
# ...

# %%
plt.figure(figsize=(7,5), facecolor='white')
plotnumber = 1

for i in df.columns:
    if plotnumber <=5:
        ax = plt.subplot(2,3, plotnumber)
        sns.boxplot(X_train[i])
        plt.xlabel(i)
    plotnumber+=1
plt.tight_layout()

# %%
from ydata_profiling import ProfileReport

# %%
report = ProfileReport(df, title="Pandas Profiling Report")

# %%
report.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.2.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-07-16 11:17:37.676277&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
sns.scatterplot(x=X_train['Frequency'], y=y)
# Out:
# <Axes: xlabel='Frequency', ylabel='Scaled sound pressure level'>

# %%
len(y.unique()) # it is a regression problem
# Out:
# 1456

# %%
sns.boxplot(y)
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
import pickle 
pickle.dump(regressor, open('model.pkl','wb'))

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
r2_score(y_test, y_pred)
# Out:
# 0.5124474986138426

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 3.7288137950232945

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 22.95466953513413

# %%
# Ridge Regression
from sklearn.linear_model import Ridge, Lasso, ElasticNet, RidgeCV, LassoCV, ElasticNetCV
ridge = RidgeCV(alphas = (0.1, 1.0, 10.0), cv = 10)
ridge.fit(X_train, y_train)
# Out:
# RidgeCV(cv=10)

# %%
ridge.alpha_
# Out:
# 0.1

# %%
ridge_lr = Ridge(alpha = ridge.alpha_)
ridge_lr.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.1)

# %%
ridge_lr.score(X_test, y_test)
# Out:
# 0.5012731346093844

# %% [markdown]
# # Elastic Net

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet, RidgeCV, LassoCV, ElasticNetCV
elastic = ElasticNetCV(alphas=None, cv= 10)
elastic.fit(X_train, y_train)
# Out:
# ElasticNetCV(cv=10)

# %%
elastic.alpha_
# Out:
# 18.85361877069057

# %%
elasticnet = ElasticNet(alpha= elastic.alpha_)
elasticnet.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=18.85361877069057)

# %%
elasticnet.score(X_test, y_test)
# Out:
# 0.1337491367339606

# %% [markdown]
# # Lasso

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet, RidgeCV, LassoCV, ElasticNetCV
lassocv = LassoCV(alphas=None, cv= 10, max_iter= 200000)
lassocv.fit(X_train, y_train)
# Out:
# LassoCV(cv=10, max_iter=200000)

# %%
lassocv.alpha_
# Out:
# 9.426809385345285

# %%
lasso = Lasso(alpha=lassocv.alpha_)

# %%
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=9.426809385345285)

# %%
lasso.score(X_train, y_train)
# Out:
# 0.2060829023265981

# %% [markdown]
# # support vector regressor

# %%
from sklearn.svm import SVR
regre = SVR()
regre.fit(X_train, y_train)
# Out:
# SVR()

# %%
y_pred=regre.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.11649932904323934

# %% [markdown]
# # Decision tree regressor

# %%
from sklearn.tree import DecisionTreeRegressor
Dec_regre = DecisionTreeRegressor(criterion='absolute_error')
Dec_regre.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='absolute_error')

# %%
y_pred = Dec_regre.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.850992706831708

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
random = RandomForestRegressor()
random.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = random.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.930579978468518

# %%
pickled_model = pickle.load(open('model.pkl', 'rb'))
pickled_model.predict(X_test)
# Out:
# array([124.06768512, 119.59316737, 120.29933092, 129.61912851,
#        129.81089779, 132.61068301, 122.44438053, 126.7461602 ,
#        129.99906397, 125.94601069, 132.50626617, 113.78942913,
#        130.10151743, 132.51123677, 123.6412694 , 114.10666435,
#        124.31679905, 126.6766228 , 129.24252599, 131.79580713,
#        125.77675782, 125.02970619, 116.44955941, 129.88018679,
#        124.2232864 , 124.67967727, 131.60657138, 124.57186337,
#        115.76458243, 123.39652912, 125.13674229, 123.92018299,
#        125.4841971 , 118.61796101, 121.70395495, 130.95730463,
#        131.39243856, 128.29169206, 121.31077749, 117.99901537,
#        126.41139865, 128.86175217, 126.44075781, 123.46463781,
#        123.08590861, 130.13707376, 125.11244177, 120.01115538,
#        123.19344296, 132.81698484, 128.72414835, 117.7903339 ,
#        123.4283675 , 122.57110308, 126.71758509, 120.44811529,
#        123.29741941, 128.68403927, 124.25898336, 123.22309466,
# ...

# %%
X_test
# Out:
#       Frequency  Angle of attack  Chord length  Free-stream velocity  \
# 51          400              0.0        0.3048                  31.7
# 1465       1250             12.3        0.1016                  31.7
# 184        2500              4.0        0.3048                  39.6
# 1000       4000              0.0        0.0254                  31.7
# 746        5000              0.0        0.0508                  55.5
# ...         ...              ...           ...                   ...
# 1295       1000              3.3        0.1016                  71.3
# 578        3150              5.4        0.1524                  39.6
# 352        1250              4.0        0.2286                  31.7
# 727        1250              0.0        0.0508                  71.3
# 1298       2000              3.3        0.1016                  71.3
#
#       Suction side displacement thickness
# 51                               0.003313
# 1465                             0.041876
# ...
